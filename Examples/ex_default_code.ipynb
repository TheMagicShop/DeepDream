# %%
from DeepDream import DefaultDream
# Out:
# ...
# 87924736/87910968 [==============================] - 0s 0us/step

# %%
from tensorflow import keras

img_url = "https://images.unsplash.com/photo-1482784160316-6eb046863ece?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=2600&q=80"
img_path = keras.utils.get_file("mountain_img", origin=img_url)
# Out:
# ...
# 1433600/1418623 [==============================] - 0s 0us/step

# %%
deepdream = DefaultDream(img_path=img_path, output_file="mountain_dream.mp4")
# Out:
# Processing octave 1... with shape (451, 676)
# 	iteration n°1: gain is 1.93
# 	iteration n°2: gain is 2.49
# 	iteration n°3: gain is 3.13
# 	iteration n°4: gain is 3.82
# 	iteration n°5: gain is 4.49
# 	iteration n°6: gain is 5.17
# 	iteration n°7: gain is 5.84
# 	iteration n°8: gain is 6.49
# 	iteration n°9: gain is 7.11
# 	iteration n°10: gain is 7.74
# 	iteration n°11: gain is 8.35
# 	iteration n°12: gain is 8.91
# 	iteration n°13: gain is 9.47
# 	iteration n°14: gain is 10.01
# 	iteration n°15: gain is 10.53
# 	iteration n°16: gain is 11.05
# 	iteration n°17: gain is 11.55
# 	iteration n°18: gain is 12.06
# 	iteration n°19: gain is 12.52
# 	iteration n°20: gain is 13.00
# 	iteration n°21: gain is 13.46
# 	iteration n°22: gain is 13.92
# 	iteration n°23: gain is 14.35
# 	iteration n°24: gain is 14.80
# 	iteration n°25: gain is 15.23
# 	iteration n°26: gain is 15.67
# 	iteration n°27: gain is 16.09
# 	iteration n°28: gain is 16.52
# 	iteration n°29: gain is 16.93
# ...

# %%
deepdream.plot_final_image
